# %% [markdown]
# <a href="https://colab.research.google.com/github/renupareek27/my-projects/blob/main/pythone_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#comment
10 + 20
# Out:
# 30

# %%
"hello world"
# Out:
# 'hello world'

# %%
"Renu  here"
# Out:
# 'Renu  here'

# %%
"this is my first python file"
# Out:
# 'this is my first python file'

# %%
"python code"
# Out:
# 'python code'

# %%
print("welcome to coding world")
# Out:
# welcome to coding world

# %%
10*3/2
# Out:
# 15.0

# %%
(10-3)*6
# Out:
# 42

# %%
13//2
# Out:
# 6

# %%
5*2
# Out:
# 10

# %%
5**2
# Out:
# 25

# %%
13/2
# Out:
# 6.5

# %%
marks = 49

# %%
marks
# Out:
# 49

# %%
type(marks)
# Out:
# int

# %%
x =True
y =False

# %%
type(x)
# Out:
# bool

# %%
type(y)
# Out:
# bool

# %%
x or y
# Out:
# True

# %%
x and y
# Out:
# False

# %%
not(x and y)
# Out:
# True

# %%
x & y
# Out:
# False

# %%
x | y
# Out:
# True

# %%
x>y
# Out:
# True

# %%
x =10
y = 5

# %%
price = 50.5
price
type(price)
# Out:
# float

# %%
print(price)
type(price)
# Out:
# 50.5
# float

# %%
name = "renu pareek"
type(name)
# Out:
# str
